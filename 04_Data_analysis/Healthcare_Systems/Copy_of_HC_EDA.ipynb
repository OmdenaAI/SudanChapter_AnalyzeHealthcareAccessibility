# %% [markdown]
# # Health Care Dataset Analysis (HC_sudan)

# %% [markdown]
# Import packages

# %%
# import packages

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load HC_sudan.csv dataset
hc_sudan = "/content/HC_sudan.csv"

pd.read_csv(hc_sudan) # Throws a Codec error while loading file. The file is not in utf-8 codec.

# %%
# Load HC_sudan.csv dataset
hc_sudan = "/content/HC_sudan.csv"


# Resolve codec issue by detecting file codec and reverting to utf-8

import chardet

# Open the file in binary mode
with open(hc_sudan, 'rb') as file:
    raw_data = file.read()

# Detect encoding
result = chardet.detect(raw_data)
print(result)         # The file is an ISO standard "Latin-1" encoding
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
# Changing the Latin-1 encoding to UTF-8 encoding

# Open the file with errors='replace'
with open(hc_sudan, 'r', encoding='utf-8', errors='replace') as file:
    data = file.read()

# Save the cleaned data to a temporary file
with open('cleaned_file.csv', 'w', encoding='utf-8') as cleaned_file:
    cleaned_file.write(data)

# Load the cleaned file with Pandas
df = pd.read_csv('cleaned_file.csv')
df.head(10)
# Out:
#                          Name          X          Y addr_city addr_street  \
# 0                           0  32.536015  15.632537         0           0
# 1                           0   0.000000   0.000000         0           0
# 2                           0  32.533961  15.528663         0           0
# 3           Wad Musa Pharmacy  32.441141  15.683439         0           0
# 4                           0   0.000000   0.000000         0           0
# 5       Ombada Model Hospital  32.419073  15.663948         0           0
# 6  Tropical Medicine Hospital  32.493623  15.640279         0           0
# 7                           0   0.000000   0.000000         0           0
# 8           Al-Hagan Pharmacy  32.444681  15.612955         0           0
# 9                           0  26.130148  11.462685         0           0
#
#     amenity  changeset_id  changeset_timestamp    changeset_user  \
# 0  pharmacy      59859075  2018-06-14 20:48:56     allasafieldin
# 1  hospital      82920351  2020-04-01 11:29:56             AARod
# 2  pharmacy      30685807  2015-05-01 09:28:35          AhmedSDN
# 3  pharmacy      89779217  2020-08-22 12:03:41             ImadJ
# 4  hospital      61428897  2018-08-07 09:45:25        ali-hasboo
# 5  hospital      91869265  2020-10-02 13:55:09    Shandiwad Mamo
# 6  hospital     110999264  2021-09-10 01:11:47           sudanix
# 7  hospital      82917752  2020-04-01 10:35:20             AARod
# 8  pharmacy      74564567  2019-09-17 08:26:04          wadsaeed
# 9    clinic      84185564  2020-04-27 09:04:02  Classic&ordinary
#
#    changeset_version  completeness dispensing      osm_id osm_type  \
# 0                  1            12        yes  5691668660     node
# 1                  1             9          0   786505555      way
# 2                  1             6          0  3490668393     node
# 3                  1            15        yes  7834704444     node
# 4                  1            12          0   614753021      way
# 5                  1             9          0  7966428285     node
# 6                  2            12          0  8006766734     node
# 7                  1             9          0   786492638      way
# 8                  1             9          0  6801517152     node
# 9                  1             6          0  7452472488     node
#
#                                uuid  Unnamed: 15
# 0  62a1f69b5e464b3a831724e7e633b9f7          NaN
# 1  6bed7ba76fdc43f2a959908df295b6c8          NaN
# 2  516a03ec3daf43e68f01ca8c8564d169          NaN
# 3  77c5b490089945198e0cfa5b45bd5c6b          NaN
# 4  5888223145234835bd0211b5475c0469          NaN
# 5  76583bb93bdb4da2ba643fe777238151          NaN
# 6  4402d3f0c21746ccae6465e2aed37f24          NaN
# 7  b2c9fbe9fd004fa09485dc701f754467          NaN
# 8  e06fd58c4a20407a9fc8725426a52dfe          NaN
# 9  afb4e326f311451b86a762a4ee16658b          NaN

# %% [markdown]
# ### Understanding the data
# - shape
# - describe
# - dtypes
# - unique values
# - missing values
# - duplicate values

# %%
df.shape
# Out:
# (1180, 16)

# %%
df.describe()
# Out:
#                  X            Y  changeset_id  changeset_version  \
# count  1180.000000  1180.000000  1.180000e+03        1180.000000
# mean     31.775855    15.186397  9.132590e+06           0.180508
# std       4.785858     2.337769  2.545192e+07           0.562129
# min       0.000000     0.000000  0.000000e+00           0.000000
# 25%      32.485813    15.534281  0.000000e+00           0.000000
# 50%      32.531007    15.597713  0.000000e+00           0.000000
# 75%      32.570649    15.641503  0.000000e+00           0.000000
# max      37.217447    20.748716  1.110008e+08           6.000000
#
#        completeness        osm_id  Unnamed: 15
# count   1180.000000  1.180000e+03          0.0
# mean       1.436441  6.434055e+09          NaN
# std        4.111490  1.582652e+09          NaN
# min        0.000000  4.922450e+07          NaN
# 25%        0.000000  6.055029e+09          NaN
# 50%        0.000000  6.953330e+09          NaN
# 75%        0.000000  7.154078e+09          NaN
# max       24.000000  1.200026e+10          NaN

# %%
print(df.dtypes)
# Out:
# Name                    object
# X                      float64
# Y                      float64
# addr_city               object
# addr_street             object
# amenity                 object
# changeset_id             int64
# changeset_timestamp     object
# changeset_user          object
# changeset_version        int64
# completeness             int64
# dispensing              object
# osm_id                   int64
# osm_type                object
# uuid                    object
# Unnamed: 15            float64
# dtype: object

# %%
df.nunique()
# Out:
# Name                    929
# X                      1089
# Y                      1109
# addr_city                 7
# addr_street              25
# amenity                   6
# changeset_id            125
# changeset_timestamp     130
# changeset_user           31
# changeset_version         6
# completeness              7
# dispensing                3
# osm_id                 1069
# osm_type                  3
# uuid                    144
# Unnamed: 15               0
# dtype: int64

# %%
df['amenity'].unique()
# Out:
# array(['pharmacy', 'hospital', 'clinic', 'doctors', 'dentist', '0'],
#       dtype=object)

# %% [markdown]
# ### Data Preparation and Cleaning
# - remove empty column
# - drop irrelevant columns
# - investigate missing values
# - check duplicates
# - rename columns

# %%
# drop unnamed/empty column
df = df.loc[:,~df.columns.str.contains('Unnamed')]
df.head()
# Out:
#                 Name          X          Y addr_city addr_street   amenity  \
# 0                  0  32.536015  15.632537         0           0  pharmacy
# 1                  0   0.000000   0.000000         0           0  hospital
# 2                  0  32.533961  15.528663         0           0  pharmacy
# 3  Wad Musa Pharmacy  32.441141  15.683439         0           0  pharmacy
# 4                  0   0.000000   0.000000         0           0  hospital
#
#    changeset_id  changeset_timestamp changeset_user  changeset_version  \
# 0      59859075  2018-06-14 20:48:56  allasafieldin                  1
# 1      82920351  2020-04-01 11:29:56          AARod                  1
# 2      30685807  2015-05-01 09:28:35       AhmedSDN                  1
# 3      89779217  2020-08-22 12:03:41          ImadJ                  1
# 4      61428897  2018-08-07 09:45:25     ali-hasboo                  1
#
#    completeness dispensing      osm_id osm_type  \
# 0            12        yes  5691668660     node
# 1             9          0   786505555      way
# 2             6          0  3490668393     node
# 3            15        yes  7834704444     node
# 4            12          0   614753021      way
#
#                                uuid
# 0  62a1f69b5e464b3a831724e7e633b9f7
# 1  6bed7ba76fdc43f2a959908df295b6c8
# 2  516a03ec3daf43e68f01ca8c8564d169
# 3  77c5b490089945198e0cfa5b45bd5c6b
# 4  5888223145234835bd0211b5475c0469

# %%
# select relevant columns and create a new DataFrame
df = df[['Name', 'X', 'Y', 'amenity', 'dispensing']].copy()
df.head()
# Out:
#                 Name          X          Y   amenity dispensing
# 0                  0  32.536015  15.632537  pharmacy        yes
# 1                  0   0.000000   0.000000  hospital          0
# 2                  0  32.533961  15.528663  pharmacy          0
# 3  Wad Musa Pharmacy  32.441141  15.683439  pharmacy        yes
# 4                  0   0.000000   0.000000  hospital          0

# %%
# addressing missing values
df.isnull().sum()
# Out:
# Name          0
# X             0
# Y             0
# amenity       0
# dispensing    0
# dtype: int64

# %%
# More quality assessment with missing values

# missing names
missing_names = df[df['Name'] == '0']
print(f"Missing facility names: {len(missing_names)}")

# invalid coordinates
invalid_coords = df[(df['X'] == 0) & (df['Y'] == 0)]
print(f"Facilities with invalid coordinates: {len(invalid_coords)}")

# missing amenity type
print(f"Missing amenity types: {(df['amenity'] == '0').sum()}")

# missing dispensing note
print(f"Missing dispensing notations: {(df['dispensing'] == '0').sum()}")
# Out:
# Missing facility names: 71
# Facilities with invalid coordinates: 25
# Missing amenity types: 9
# Missing dispensing notations: 1148

# %%
# assessing duplicates

print(f"Number of duplicates: {df.duplicated().sum()}")
# Out:
# Number of duplicates: 9

# %%
# locating duplicate observations

df.loc[df.duplicated(),]
# Out:
#                    Name    X    Y   amenity dispensing
# 4                     0  0.0  0.0  hospital          0
# 7                     0  0.0  0.0  hospital          0
# 16                    0  0.0  0.0  hospital          0
# 24                    0  0.0  0.0  hospital          0
# 32                    0  0.0  0.0  hospital          0
# 58                    0  0.0  0.0  hospital          0
# 90   Mecca Eye Hospital  0.0  0.0  hospital          0
# 109                   0  0.0  0.0  hospital          0
# 137                   0  0.0  0.0  hospital          0

# %%
df.loc[(df['Name'] == 'Mecca Eye Hospital')]
# Out:
#                    Name          X          Y   amenity dispensing
# 83   Mecca Eye Hospital   0.000000   0.000000  hospital          0
# 90   Mecca Eye Hospital   0.000000   0.000000  hospital          0
# 773  Mecca Eye Hospital  32.486939  15.665188  hospital          0

# %%
df.iloc[90,]
# Out:
# Name          Mecca Eye Hospital
# X                            0.0
# Y                            0.0
# amenity                 hospital
# dispensing                     0
# Name: 90, dtype: object

# %%
# # drop the row with index 90
# df = df.drop(index=90)

# # Reset the index and drop the old one
# df = df.reset_index(drop=True)

# %%
# df.iloc[90,]

# %%
# renaming column

df.rename(columns={'amenity':'Amenity', 'dispensing':'Dispensing'}, inplace=True)
df.head(), df.shape
# Out:
# (                Name          X          Y   Amenity Dispensing
#  0                  0  32.536015  15.632537  pharmacy        yes
#  1                  0   0.000000   0.000000  hospital          0
#  2                  0  32.533961  15.528663  pharmacy          0
#  3  Wad Musa Pharmacy  32.441141  15.683439  pharmacy        yes
#  4                  0   0.000000   0.000000  hospital          0,
#  (1180, 5))

# %% [markdown]
# ### Feature Understanding
#
# Univariate Analysis

# %%
# plotting Amenity distributions

ax = sns.barplot(x=df['Amenity'].value_counts().index, y=df['Amenity'].value_counts())

# adding value annotations on each bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}',  # Text is the height of the bar
                (p.get_x() + p.get_width() / 2., p.get_height()),  # Position: center of the bar
                ha='center', va='bottom', fontsize=10)  # Alignment and font size

plt.title('Amenity Distribution')
plt.xlabel('Amenity Type')
plt.ylabel('Count')
plt.show()

# %%
# dispensing distribution

ax = sns.barplot(x=df['Dispensing'].value_counts().index, y=df['Dispensing'].value_counts())

# adding value annotations on each bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}',  # Text is the height of the bar
                (p.get_x() + p.get_width() / 2., p.get_height()),  # Position: center of the bar
                ha='center', va='bottom', fontsize=10)  # Alignment and font size

plt.title('Dispensing Distribution')
plt.xlabel('Dispensing Type')
plt.ylabel('Count')
plt.show()

# %%
# create a count plot to visualize the relationship
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Amenity', hue='Dispensing')

# add plot labels and title
plt.title('Dispensing Status by Amenity', fontsize=16)
plt.xlabel('Amenity Type', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(title='Dispensing', loc='upper right')

plt.show()

# %%
# Filter the data to exclude rows where Amenity is 'pharmacy'
df_filtered = df[df['Amenity'] != 'pharmacy']

# Create a count plot to visualize the dispensing status for each amenity (excluding pharmacy)
plt.figure(figsize=(10, 6))
sns.countplot(data=df_filtered, x='Amenity', hue='Dispensing')

# Add plot labels and title
plt.title('Dispensing Status by Amenity (Excluding Pharmacy)', fontsize=16)
plt.xlabel('Amenity Type', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(title='Dispensing', loc='upper right')

# Show the plot
plt.show()

# %%
(df['Amenity'] == 'hospital').sum()
# Out:
# 101

# %%
((df['Amenity'] == 'hospital') & (df['Dispensing'] == 'yes')).sum()
# Out:
# 0

# %%
# Implement graphical representation of health facilities
import folium

# Create map
map_center = [15.5974, 32.5356]  # Adjust to center on your area
m = folium.Map(location=map_center, zoom_start=14)

# Add facilities to the map
for _, row in df.iterrows():
    if row['X'] != 0 and row['Y'] != 0:  # Ignore invalid coordinates
        color = 'green' if row['Dispensing'] == 'yes' else 'red'
        folium.Marker([row['Y'], row['X']], popup=row['Name'], icon=folium.Icon(color=color)).add_to(m)

# Show map
m.save("health_facilities_map.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6482c550f7ce5084634da0f81c626e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6482c550f7ce5084634da0f81c626e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6482c550f7ce5084634da0f81c626e4 = L.map(
#                 &quot;map_d6482c550f7ce5084634da0f81c626e4&quot;,
#                 {
#                     center: [15.5974, 32.5356],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93c904254236d4c34e22e9be0032b533 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_93c904254236d4c34e22e9be0032b533.addTo(map_d6482c550f7ce5084634da0f81c626e4);
#
#
#             var marker_62fb064870918222a4e0574d67c6de82 = L.marker(
#                 [15.63253679, 32.53601515],
#                 {
# }
#             ).addTo(map_d6482c550f7ce5084634da0f81c626e4);
#
#
#             var icon_d7ab03a50661ee785d22bfad78c9f91f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_62fb064870918222a4e0574d67c6de82.setIcon(icon_d7ab03a50661ee785d22bfad78c9f91f);
#
#
#         var popup_4a21be6304d15d91dce3d892f423ba5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72c24484ae65bd67d6f33bef797176f3 = $(`&lt;div id=&quot;html_72c24484ae65bd67d6f33bef797176f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_4a21be6304d15d91dce3d892f423ba5b.setContent(html_72c24484ae65bd67d6f33bef797176f3);
#
#
#
#         marker_62fb064870918222a4e0574d67c6de82.bindPopup(popup_4a21be6304d15d91dce3d892f423ba5b)
#         ;
#
#
#
#
#             var marker_197ea2aece206fdf1bc53f4481efbef5 = L.marker(
#                 [15.52866322, 32.53396142],
#                 {
# }
#             ).addTo(map_d6482c550f7ce5084634da0f81c626e4);
#
#
#             var icon_4f9af2eb1c27ca728f44321f379f523e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_197ea2aece206fdf1bc53f4481efbef5.setIcon(icon_4f9af2eb1c27ca728f44321f379f523e);
#
#
#         var popup_12aaedb5d213a981977f6db51ea1e8c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c57d50fc6a2644a7d95b0a234ef751f8 = $(`&lt;div id=&quot;html_c57d50fc6a2644a7d95b0a234ef751f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_12aaedb5d213a981977f6db51ea1e8c4.setContent(html_c57d50fc6a2644a7d95b0a234ef751f8);
#
#
#
#         marker_197ea2aece206fdf1bc53f4481efbef5.bindPopup(popup_12aaedb5d213a981977f6db51ea1e8c4)
#         ;
#
#
#
#
#             var marker_e3542058bc5cfc04b270bf1ab6b82d23 = L.marker(
#                 [15.68343917, 32.44114114],
#                 {
# }
#             ).addTo(map_d6482c550f7ce5084634da0f81c626e4);
#
#
#             var icon_f94c8a55d9395501c57289f97dd319d4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_e3542058bc5cfc04b270bf1ab6b82d23.setIcon(icon_f94c8a55d9395501c57289f97dd319d4);
#
#
#         var popup_26414bfa357ec32ada3b060352788312 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00665ca8d2d24908c10629208f82849b = $(`&lt;div id=&quot;html_00665ca8d2d24908c10629208f82849b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wad Musa Pharmacy&lt;/div&gt;`)[0];
#                 popup_26414bfa357ec32ada3b060352788312.setContent(html_00665ca8d2d24908c10629208f82849b);
#
#
#
#         marker_e3542058bc5cfc04b270bf1ab6b82d23.bindPopup(popup_26414bfa357ec32ada3b060352788312)
#         ;
#
#
#
#
#             var marker_ab47eea39eb4fdf16902b255dbe140aa = L.marker(
#                 [15.66394764, 32.41907302],
#                 {
# }
#             ).addTo(map_d6482c550f7ce5084634da0f81c626e4);
#
#
#             var icon_318e26eb917432f1ccc1f44764ea0f9d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;ic
