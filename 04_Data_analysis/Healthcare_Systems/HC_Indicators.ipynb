# %% [markdown]
# <a href="https://colab.research.google.com/github/OmdenaAI/SudanChapter_AnalyzeHealthcareAccessibility/blob/main/04_Data_analysis/Healthcare_Systems/HC_Indicators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Healthcare Data Analysis (Indicator dataset)

# %% [markdown]
# ### Import packages and load file

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# load file

df = pd.read_csv("HC_indicators.csv")
df.head()
# Out:
#                      GHO (CODE)  \
# 0               #indicator+code
# 1  PHE_HHAIR_POP_CATEGORY_FUELS
# 2                       NCD_PAA
# 3               LIFE_0000000033
# 4                   TB_c_newinc
#
#                                        GHO (DISPLAY) YEAR (DISPLAY)  \
# 0                                    #indicator+name     #date+year
# 1  Population with primary reliance on fuels and ...           2024
# 2  Prevalence of insufficient physical activity a...           2024
# 3    nLx - person-years lived between ages x and x+n           2023
# 4               Tuberculosis - new and relapse cases           2023
#
#   COUNTRY (DISPLAY) DIMENSION (NAME)        VALUE
# 0     #country+name  #dimension+name     #numeric
# 1             Sudan            Urban       0.0543
# 2             Sudan           Female    26.649185
# 3             Sudan       Both sexes  451194.0274
# 4             Sudan              NaN        27562

# %%
# accessing the GHO (Display) coloumn

df['GHO (DISPLAY)']
# Out:
# 0                                          #indicator+name
# 1        Population with primary reliance on fuels and ...
# 2        Prevalence of insufficient physical activity a...
# 3          nLx - person-years lived between ages x and x+n
# 4                     Tuberculosis - new and relapse cases
#                                ...
# 18297    nqx - probability of dying between ages x and x+n
# 18298                  Tx - person-years lived above age x
# 18299    Distribution of causes of death among children...
# 18300    Population pushed below the $2.15 a day povert...
# 18301    Prevalence of obesity among children and adole...
# Name: GHO (DISPLAY), Length: 18302, dtype: object

# %%
# display full string content

pd.set_option('display.max_colwidth', None)
df['GHO (DISPLAY)']
# Out:
# 0                                                                                                                 #indicator+name
# 1                              Population with primary reliance on fuels and technologies for cooking, by fuel type (in millions)
# 2                        Prevalence of insufficient physical activity among adults aged 18+ years (age-standardized estimate) (%)
# 3                                                                                 nLx - person-years lived between ages x and x+n
# 4                                                                                            Tuberculosis - new and relapse cases
#                                                                    ...
# 18297                                                                           nqx - probability of dying between ages x and x+n
# 18298                                                                                         Tx - person-years lived above age x
# 18299                                                           Distribution of causes of death among children aged < 5 years (%)
# 18300           Population pushed below the $2.15 a day poverty line by household health expenditures (%, national, rural, urban)
# 18301    Prevalence of obesity among children and adolescents, BMI > +2 standard deviations above the median (crude estimate) (%)
# Name: GHO (DISPLAY), Length: 18302, dtype: object

# %% [markdown]
# ### Begin GHO (Display) column preprocessing
# -- Creating tokens
# - Remove punctuation
# - Uniform case
# - Tokenization implementation
# - Stopword removal

# %%
# downloading 'punkt_tab'

# !pip install nltk
nltk.download('punkt_tab')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# preprocess the "GHO (DISPLAY)" column into tokens

def preprocess_text(text):
    text = re.sub(r'[^\w\s]', '', text)  # remove punctuation
    text = text.lower()  # convert to lowercase
    tokens = word_tokenize(text)  # tokenize
    tokens = [word for word in tokens if word not in stopwords.words('english')]  # remove stopwords
    return tokens

df['processed_text'] = df['GHO (DISPLAY)'].apply(preprocess_text) # display 'preprocessed_text' column

# %%
df['processed_text']
# Out:
# 0                                                                                                   [indicatorname]
# 1                               [population, primary, reliance, fuels, technologies, cooking, fuel, type, millions]
# 2         [prevalence, insufficient, physical, activity, among, adults, aged, 18, years, agestandardized, estimate]
# 3                                                                            [nlx, personyears, lived, ages, x, xn]
# 4                                                                               [tuberculosis, new, relapse, cases]
#                                                             ...
# 18297                                                                        [nqx, probability, dying, ages, x, xn]
# 18298                                                                              [tx, personyears, lived, age, x]
# 18299                                                [distribution, causes, death, among, children, aged, 5, years]
# 18300        [population, pushed, 215, day, poverty, line, household, health, expenditures, national, rural, urban]
# 18301    [prevalence, obesity, among, children, adolescents, bmi, 2, standard, deviations, median, crude, estimate]
# Name: processed_text, Length: 18302, dtype: object

# %%
# flattenning token list
all_tokens = [word for tokens in df['processed_text'] for word in tokens]

print("Number of tokens:", len(all_tokens))
print(all_tokens)
# Out:
# Number of tokens: 135703
# ['indicatorname', 'population', 'primary', 'reliance', 'fuels', 'technologies', 'cooking', 'fuel', 'type', 'millions', 'prevalence', 'insufficient', 'physical', 'activity', 'among', 'adults', 'aged', '18', 'years', 'agestandardized', 'estimate', 'nlx', 'personyears', 'lived', 'ages', 'x', 'xn', 'tuberculosis', 'new', 'relapse', 'cases', 'total', 'density', 'per', 'million', 'population', 'telecobalt', 'unit', 'ndx', 'number', 'people', 'dying', 'ages', 'x', 'xn', 'number', 'deaths', 'among', 'adolescents', '10', '19', 'years', 'age', 'insufficiently', 'active', 'crude', 'estimate', 'tx', 'personyears', 'lived', 'age', 'x', 'estimated', 'antiretroviral', 'therapy', 'coverage', 'among', 'people', 'living', 'hiv', 'current', 'health', 'expenditure', 'che', 'per', 'capita', 'us', 'raised', 'fasting', 'blood', 'glucose', '70', 'mmoll', 'crude', 'estimate', 'deaths', 'per', '1', '000', 'live', 'births', 'alcohol', 'recorded', 'per', 'capita', '15', 'consumption', 'litres', 'pure', 'alcohol', 'proportion', 'population', 'primary', 'reliance', 'fuels', 'technologies', 'cooking', 'fuel', 'type', 'prevalence', 'overweight', 'among', 'children', 'adolescents', 'bmi', '1', 'standard', 'deviations', 'median', 'crude', 'estimate', 'prevalence', 'underweight', 'among', 'adults', 'bmi', '18', 'crude', 'estimate', 'prevalence', 'overweight', 'among', 'adults', 'bmi', 'greaterequal', '25', 'agestandardized', 'estimate', 'prevalence', 'anaemia', 'children', 'aged', '659', 'months', 'severe', 'wasted', 'prevalence', 'among', 'children', '5', 'years', 'age', 'weightforheight', '3', 'sd', 'surveybased', 'estimates', 'distribution', 'causes', 'death', 'among', 'children', 'aged', '5', 'years', 'nqx', 'probability', 'dying', 'ages', 'x', 'xn', 'distribution', 'causes', 'death', 'among', 'children', 'aged', '5', 'years', 'number', 'deaths', 'among', 'children', 'ages', '5', '9', 'years', 'number', 'underfive', 'deaths', 'measlescontainingvaccine', 'firstdose', 'mcv1', 'immunization', 'coverage', 'among', '1yearolds', 'severe', 'wasted', 'prevalence', 'among', 'children', '5', 'years', 'age', 'weightforheight', '3', 'sd', 'surveybased', 'estimates', 'ex', 'expectation', 'life', 'age', 'x', 'number', 'deaths', 'number', 'new', 'hiv', 'infections', 'alcohol', 'total', 'recorded', 'unrecorded', 'per', 'capita', '15', 'consumption', 'projections', 'mean', 'total', 'cholesterol', 'crude', 'underweight', 'prevalence', 'among', 'children', '5', 'years', 'age', 'weightforage', '2', 'sd', 'surveybased', 'estimates', 'infant', 'mortality', 'rate', 'probability', 'dying', 'birth', 'age', '1', 'per', '1000', 'live', 'births', 'lx', 'number', 'people', 'left', 'alive', 'age', 'x', 'infant', 'mortality', 'rate', 'probability', 'dying', 'birth', 'age', '1', 'per', '1000', 'live', 'births', 'prevalence', 'overweight', 'among', 'adults', 'bmi', 'greaterequal', '25', 'crude', 'estimate', 'number', 'deaths', 'raised', 'fasting', 'blood', 'glucose', '70', 'mmoll', 'crude', 'estimate', 'number', 'confirmed', 'malaria', 'cases', 'number', 'deaths', 'oral', 'health', 'basic', 'restorative', 'dental', 'procedures', 'treat', 'existing', 'dental', 'decay', 'relapse', 'cases', 'extrapulmonary', 'domestic', 'general', 'government', 'health', 'expenditure', 'gghed', 'percentage', 'general', 'government', 'expenditure', 'gge', 'number', 'pregnant', 'women', 'aged', '1549', 'years', 'anaemia', 'thousands', 'severe', 'wasted', 'prevalence', 'among', 'children', '5', 'years', 'age', 'weightforheight', '3', 'sd', 'surveybased', 'estimates', 'number', 'deaths', 'ex', 'expectation', 'life', 'age', 'x', 'wasting', 'prevalence', 'among', 'children', '5', 'years', 'age', 'weightforheight', '2', 'sd', 'surveybased', 'estimates', 'total', 'expenditure', 'dental', 'healthcare', 'million', 'us', 'proportion', 'population', 'primary', 'reliance', 'fuels', 'technologies', 'cooking', 'fuel', 'type', 'wasting', 'prevalence', 'among', 'children', '5', 'years', 'age', 'weightforheight', '2', 'sd', 's ...

# %%
# checking the list of most common keywords
keywords = Counter(all_tokens).most_common(50)
print("Number of common tokens:", len(keywords))
print("Most common keywords:", keywords)
# Out:
# Number of common tokens: 50
# Most common keywords: [('number', 4004), ('among', 3914), ('children', 3119), ('deaths', 3117), ('per', 3078), ('age', 2976), ('years', 2745), ('prevalence', 2706), ('population', 2531), ('5', 2016), ('x', 1995), ('estimate', 1951), ('aged', 1910), ('crude', 1854), ('rate', 1603), ('primary', 1592), ('1', 1560), ('000', 1558), ('reliance', 1538), ('fuels', 1538), ('technologies', 1538), ('cooking', 1538), ('bmi', 1485), ('type', 1438), ('alcohol', 1425), ('agestandardized', 1370), ('ages', 1362), ('births', 1256), ('live', 1230), ('adolescents', 1227), ('dying', 1223), ('fuel', 1151), ('death', 1148), ('xn', 1140), ('health', 1121), ('mortality', 1105), ('2', 1059), ('standard', 916), ('probability', 915), ('median', 910), ('deviations', 891), ('1000', 886), ('mean', 852), ('proportion', 843), ('millions', 826), ('adults', 790), ('causes', 777), ('distribution', 755), ('cases', 741), ('people', 740)]

# %%
# defining simple keyword groups
categories = {
    'prevalence': ['prevalence', 'rate'],
    'deaths': ['deaths', 'dying', 'mortality'],
    'health': ['health', 'therapy', 'treatment', 'glucose', 'expenditure'],
    'nutrition': ['anaemia', 'underweight', 'overweight', 'wasted'],
    'activity': ['activity', 'active']
}

# assign categories to rows
def categorize(row):
    for category, words in categories.items():
        if any(word in row for word in words):
            return category
    return 'other'

df['category'] = df['processed_text'].apply(lambda x: categorize(x))

print(categories.items())
# Out:
# dict_items([('prevalence', ['prevalence', 'rate']), ('deaths', ['deaths', 'dying', 'mortality']), ('health', ['health', 'therapy', 'treatment', 'glucose', 'expenditure']), ('nutrition', ['anaemia', 'underweight', 'overweight', 'wasted']), ('activity', ['activity', 'active'])])

# %%
df['category']
# Out:
# 0             other
# 1             other
# 2        prevalence
# 3             other
# 4             other
#             ...
# 18297        deaths
# 18298         other
# 18299         other
# 18300        health
# 18301    prevalence
# Name: category, Length: 18302, dtype: object

# %%
print(df['category'].value_counts())
# Out:
# category
# other         8096
# prevalence    4309
# deaths        3710
# health        1699
# nutrition      424
# activity        64
# Name: count, dtype: int64

# %% [markdown]
# ### Cleaning the indicator dataset

# %%
df.head()
# Out:
#                      GHO (CODE)  \
# 0               #indicator+code
# 1  PHE_HHAIR_POP_CATEGORY_FUELS
# 2                       NCD_PAA
# 3               LIFE_0000000033
# 4                   TB_c_newinc
#
#                                                                                               GHO (DISPLAY)  \
# 0                                                                                           #indicator+name
# 1        Population with primary reliance on fuels and technologies for cooking, by fuel type (in millions)
# 2  Prevalence of insufficient physical activity among adults aged 18+ years (age-standardized estimate) (%)
# 3                                                           nLx - person-years lived between ages x and x+n
# 4                                                                      Tuberculosis - new and relapse cases
#
#   YEAR (DISPLAY) COUNTRY (DISPLAY) DIMENSION (NAME)        VALUE  \
# 0     #date+year     #country+name  #dimension+name     #numeric
# 1           2024             Sudan            Urban       0.0543
# 2           2024             Sudan           Female    26.649185
# 3           2023             Sudan       Both sexes  451194.0274
# 4           2023             Sudan              NaN        27562
#
#                                                                                               processed_text  \
# 0                                                                                            [indicatorname]
# 1                        [population, primary, reliance, fuels, technologies, cooking, fuel, type, millions]
# 2  [prevalence, insufficient, physical, activity, among, adults, aged, 18, years, agestandardized, estimate]
# 3                                                                     [nlx, personyears, lived, ages, x, xn]
# 4                                                                        [tuberculosis, new, relapse, cases]
#
#      category
# 0       other
# 1       other
# 2  prevalence
# 3       other
# 4       other

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18302 entries, 0 to 18301
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GHO (CODE)         18302 non-null  object
#  1   GHO (DISPLAY)      18302 non-null  object
#  2   YEAR (DISPLAY)     18302 non-null  object
#  3   COUNTRY (DISPLAY)  18302 non-null  object
#  4   DIMENSION (NAME)   14864 non-null  object
#  5   VALUE              18302 non-null  object
#  6   processed_text     18302 non-null  object
#  7   category           18302 non-null  object
# dtypes: object(8)
# memory usage: 1.1+ MB

# %%
df.columns # checking column names to rename
# Out:
# Index(['GHO (CODE)', 'GHO (DISPLAY)', 'YEAR (DISPLAY)', 'COUNTRY (DISPLAY)',
#        'DIMENSION (NAME)', 'VALUE', 'processed_text', 'category'],
#       dtype='object')

# %%
# renaming column names

df.rename(columns={'DIMENSION (NAME)': 'dimension', 'YEAR (DISPLAY)': 'year', 'VALUE': 'value', 'category': 'gho_category', \
                       'COUNTRY (DISPLAY)': 'country'}, inplace=True)
df.columns
# Out:
# Index(['GHO (CODE)', 'GHO (DISPLAY)', 'year', 'country', 'dimension', 'value',
#        'processed_text', 'gho_category'],
#       dtype='object')

# %%
# Saving the output in a CSV file
# df.to_csv('output.csv', index=False)

# %%
# selecting features
new_df = df[['country', 'year', 'dimension', 'value', 'gho_category']]

# dropping the first row
new_df = new_df.iloc[1:].copy()

# Displaying information about the DataFrame
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18301 entries, 1 to 18301
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       18301 non-null  object
#  1   year          18301 non-null  object
#  2   dimension     14863 non-null  object
#  3   value         18301 non-null  object
#  4   gho_category  18301 non-null  object
# dtypes: object(5)
# memory usage: 715.0+ KB

# %%
new_df['value'].dtype
# Out:
# dtype('O')

# %%
# coercing 'value' dtype

new_df['value'] = new_df['value'].astype(float)
new_df['value'].dtype
# Out:
# dtype('float64')

# %%
print(new_df['value'].unique(), "\n", new_df['gho_category'].unique())  # Display all unique values
# Out:
# [5.43000000e-02 2.66491850e+01 4.51194027e+05 ... 1.20300000e-02
#  1.95552175e+06 2.03940000e+00]
#  ['other' 'prevalence' 'deaths' 'activity' 'health' 'nutrition']

# %% [markdown]
# ### Creating visuals
# - Some EDA
# - Create Visuals

# %%
grouped = pd.DataFrame(new_df.groupby(['year', 'gho_category'])['value'].sum())

grouped.head(10)
# Out:
#                           value
# year gho_category
# 1953 deaths        1.203000e-02
#      health        3.190000e+00
#      other         2.034855e+06
#      prevalence    2.039400e+00
# 1954 deaths        4.309806e+03
#      other         1.445142e+03
#      prevalence    6.599375e+00
# 1955 deaths        0.000000e+00
#      health        0.000000e+00
#      other         9.801046e+03

# %%
# Restructuring the DataFrame
reshaped_grouped = grouped.reset_index().pivot(index='year', columns= 'gho_category', values= 'value')

# Display the result
print(reshaped_grouped)
# Out:
# gho_category   activity         deaths        health    nutrition  \
# year
# 1953                NaN       0.012030  3.190000e+00          NaN
# 1954                NaN    4309.806320           NaN          NaN
# 1955                NaN       0.000000  0.000000e+00          NaN
# 1956                NaN   10270.366070  0.000000e+00          NaN
# 1957                NaN    1365.688640           NaN          NaN
# ...                 ...            ...           ...          ...
# 2020          90.621570  899959.496490  4.414681e+02   8159.67375
# 2021          90.647975  959912.019965  5.832880e+06  19270.16155
# 2022          90.022745  846113.008420  4.982395e+06   8326.60000
# 2023          88.170300   25495.779520           NaN          NaN
# 2024                NaN            NaN           NaN          NaN
#
# gho_category         other   prevalence
# year
# 1953          2.034855e+06     2.039400
# 1954          1.445142e+03     6.599375
# 1955          9.801046e+03    64.245520
# 1956          8.993862e+02    47.877975
# 1957          2.294953e+05    62.762900
# ...                    ...          ...
# 2020          3.170719e+07  2249.998315
# 2021          2.413121e+07  2857.876675
# 2022          3.522684e+07  2253.454890
# 2023          4.950744e+06          NaN
# 2024          5.430000e-02    26.649185
#
# [72 rows x 6 columns]
