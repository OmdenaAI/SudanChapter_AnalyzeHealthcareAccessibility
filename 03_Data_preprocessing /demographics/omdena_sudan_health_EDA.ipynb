# %% [markdown]
# <a href="https://colab.research.google.com/github/OmdenaAI/SudanChapter_AnalyzeHealthcareAccessibility/blob/main/03_Data_preprocessing%20/demographics/omdena_sudan_health_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file_path = "/content/drive/MyDrive/Omdena-Health_Sudan/demographicsAlt.csv"

# %%
import pandas as pd

# %%
data = pd.read_csv(file_path)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5044 entries, 0 to 5043
# Data columns (total 87 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Unnamed: 0                            5044 non-null   int64
#  1   Region, subregion, country or area *  5044 non-null   object
#  2   Location code                         5044 non-null   int64
#  3   ISO3 Alpha-code                       5044 non-null   object
#  4   ISO2 Alpha-code                       5044 non-null   object
#  5   Type                                  5044 non-null   object
#  6   Parent code                           5044 non-null   int64
#  7   indicator                             5043 non-null   object
#  8   gender                                5044 non-null   object
#  9   quintile                              5044 non-null   int64
#  10  ages                                  1250 non-null   object
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0  Location code  Parent code     quintile  \
# count  5044.000000         5044.0       5044.0  5044.000000
# mean   2521.500000          729.0        912.0     7.842982
# std    1456.221709            0.0          0.0     2.479007
# min       0.000000          729.0        912.0     1.000000
# 25%    1260.750000          729.0        912.0     9.000000
# 50%    2521.500000          729.0        912.0     9.000000
# 75%    3782.250000          729.0        912.0     9.000000
# max    5043.000000          729.0        912.0     9.000000
#
#        non-zero-year-columns       1950.0       1951.0       1952.0  \
# count            5044.000000  5044.000000  5044.000000  5044.000000
# mean               14.346947     5.092267     5.197863     5.313213
# std                18.387822   138.666052   142.703345   146.911051
# min                 0.000000     0.000000     0.000000     0.000000
# 25%                 1.000000     0.000000     0.000000     0.000000
# ...

# %%
# drop 'Unnamed: 0' column
data.drop(columns=["Unnamed: 0"], inplace=True)

# %%
# rename 'Region, subregion, country or area *' column
data.rename(columns={"Region, subregion, country or area *": "Region_country_area"}, inplace=True)

# %%
data[["Region_country_area","quintile", "1950.0", "1980.0", "2022.0", "2023.0"]].sample(20)
# Out:
#      Region_country_area  quintile  1950.0  1980.0  2022.0  2023.0
# 4247               Sudan         9     0.0    0.00   6.000   6.000
# 925                Sudan         9     0.0    0.62   0.000   0.000
# 4560               Sudan         9     0.0    0.00   0.000   0.000
# 440                Sudan         4     0.0    0.00   0.000   0.000
# 51                 Sudan         9     0.0    0.00   0.000   0.000
# 520                Sudan         9     0.0    0.51   0.000   0.000
# 4579               Sudan         9     0.0    0.00   0.000   0.000
# 4946               Sudan         9     0.0    0.00   0.000   0.000
# 1044               Sudan         9     0.0  862.00   0.000   0.000
# 3999               Sudan         9     0.0    0.00   0.000   0.000
# 4908               Sudan         9     0.0    0.00  12.872  17.473
# 3                  Sudan         9     0.0    0.00   0.000   0.000
# 149                Sudan         9     0.0    0.00   0.000   0.000
# ...

# %%
cols = list(data.columns)

# %%
cols
# Out:
# ['Unnamed: 0',
#  'Region, subregion, country or area *',
#  'Location code',
#  'ISO3 Alpha-code',
#  'ISO2 Alpha-code',
#  'Type',
#  'Parent code',
#  'indicator',
#  'gender',
#  'quintile',
#  'ages',
#  'values are in percentage',
#  'non-zero-year-columns',
#  '1950.0',
#  '1951.0',
#  '1952.0',
#  '1953.0',
#  '1954.0',
#  '1955.0',
#  '1956.0',
#  '1957.0',
#  '1958.0',
#  '1959.0',
#  '1960.0',
#  '1961.0',
#  '1962.0',
#  '1963.0',
#  '1964.0',
#  '1965.0',
#  '1966.0',
#  '1967.0',
#  '1968.0',
#  '1969.0',
#  '1970.0',
#  '1971.0',
#  '1972.0',
#  '1973.0',
#  '1974.0',
#  '1975.0',
#  '1976.0',
#  '1977.0',
#  '1978.0',
#  '1979.0',
#  '1980.0',
#  '1981.0',
#  '1982.0',
#  '1983.0',
#  '1984.0',
#  '1985.0',
#  '1986.0',
#  '1987.0',
#  '1988.0',
#  '1989.0',
#  '1990.0',
#  '1991.0',
#  '1992.0',
#  '1993.0',
#  '1994.0',
#  '1995.0',
#  '1996.0',
#  '1997.0',
#  '1998.0',
#  '1999.0',
#  '2000.0',
#  '2001.0',
#  '2002.0',
#  '2003.0',
#  '2004.0',
#  '2005.0',
# ...
